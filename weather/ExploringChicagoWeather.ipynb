# %% [markdown]
# # Exploring Chicago Weather
#
# Based on my work in the "Exploring NOAA GSOD Weather Stations" Jupyter notebook, I'll now retrieve data just for the Chicago Midway Airport weather station and do some analysis on that data. I'll also merge in cloudcover data I retrieved from Visual Crossing.
#
# Based on the prior work, I determined that the Chicago Midway Airport weather station has the unique identifiers of `USAF` = 725340, `WBAN` = 14819 and that there are data files for years 1973 through 2024. To match the data from Visual Crossing, I'll only retrieve years 2000 to 2024.

# %%
import pandas as pd

# %%
# This cloud cover data is retrieved from https://www.visualcrossing.com/weather/weather-data-services
cloud_cover = pd.read_csv('chicago, il 2000-01-01 to 2024-05-14 - CLOUD COVER.csv')
print(f"Retrieved {len(cloud_cover)} records.")
cloud_cover['datetime'] = pd.to_datetime(cloud_cover['datetime'])
cloud_cover = cloud_cover.rename(columns={'datetime': 'date'})
# Let's see what the last 100 days with less than 50% cloud cover were
cloud_cover[cloud_cover['cloudcover'] < 50][-100:]
# Out:
# Retrieved 8901 records.
#            date  cloudcover
# 8574 2023-06-23        48.1
# 8575 2023-06-24        29.3
# 8584 2023-07-03        39.6
# 8585 2023-07-04        33.5
# 8590 2023-07-09        31.9
# ...         ...         ...
# 8881 2024-04-25        40.7
# 8886 2024-04-30        27.6
# 8894 2024-05-08        34.5
# 8897 2024-05-11        41.8
# 8898 2024-05-12        44.5
#
# [100 rows x 2 columns]

# %%
def getAllDataGSOD(usaf, wban, beginYear, endYear):
    data = []
    for year in range(int(beginYear), int(endYear) + 1):
        requestUrl = f"https://www.ncei.noaa.gov/data/global-summary-of-the-day/access/{year}/{usaf}{wban}.csv"
        print(f"Retrieving data for {year}")
        # We need to cast FRSHTT column as a string because it looks like a string of zeroes and ones 
        # and would otherwise be interpreted as an integer
        data.append(pd.read_csv(requestUrl, dtype={'FRSHTT': 'string'}))
    return pd.concat(data)
        
gsod = getAllDataGSOD(usaf = 725340, wban = 14819, beginYear = 2000, endYear = 2024)
# How many rows do we have?
print(f"Rows returned: {gsod.shape[0]}")
# Out:
# Retrieving data for 2000
# Retrieving data for 2001
# Retrieving data for 2002
# Retrieving data for 2003
# Retrieving data for 2004
# Retrieving data for 2005
# Retrieving data for 2006
# Retrieving data for 2007
# Retrieving data for 2008
# Retrieving data for 2009
# Retrieving data for 2010
# Retrieving data for 2011
# Retrieving data for 2012
# Retrieving data for 2013
# Retrieving data for 2014
# Retrieving data for 2015
# Retrieving data for 2016
# Retrieving data for 2017
# Retrieving data for 2018
# Retrieving data for 2019
# Retrieving data for 2020
# Retrieving data for 2021
# Retrieving data for 2022
# Retrieving data for 2023
# Retrieving data for 2024
# Rows returned: 8900

# %% [markdown]
# ## Data Cleaning
#
# Now let's apply the same data cleaning we applied in the "Exploring NOAA GSOD Weather Stations" Jupyter notebook.

# %%
# I only care about these basic parameters
gsod = gsod[['DATE', 'NAME', 'TEMP', 'MIN', 'MAX', 'PRCP', 'SNDP', 'FRSHTT']]
gsod = gsod.rename(columns={'DATE': 'date', 
                            'NAME': 'station_name', 
                            'TEMP': 'avg_temp', 
                            'MIN': 'min_temp', 
                            'MAX': 'max_temp',
                            'PRCP': 'precipitation_depth',
                            'SNDP': 'snow_depth'})
# Ignore any observations where the temperature min/max was invalid
gsod = gsod[(gsod['min_temp'] < 9999.9) & (gsod['max_temp'] < 9999.9)].copy()

# FRSHTT is a binary bit mask indicating presence of Fog, Rain, Snow, Hail, Thunder, and Tornado
# gsod['fog']     = gsod['FRSHTT'].apply(lambda s: bool(int(s, 2) & int('100000', 2)))
gsod['rain']    = gsod['FRSHTT'].apply(lambda s: bool(int(s, 2) & int('010000', 2)))
gsod['snow']    = gsod['FRSHTT'].apply(lambda s: bool(int(s, 2) & int('001000', 2)))
# gsod['hail']    = gsod['FRSHTT'].apply(lambda s: bool(int(s, 2) & int('000100', 2)))
# gsod['thunder'] = gsod['FRSHTT'].apply(lambda s: bool(int(s, 2) & int('000010', 2)))
# gsod['tornado'] = gsod['FRSHTT'].apply(lambda s: bool(int(s, 2) & int('000001', 2)))
gsod = gsod.drop(columns=['FRSHTT'])

# For the `SNDP` and `PRCP` values, if there is no snow accumulation or rain precipitation 
# then 999.9 or 99.99 (respectively) may appear as a value. For my purposes, it would be
# more helpful if these showed up as 0.
gsod.loc[gsod['snow_depth'] == 999.9, 'snow_depth'] = 0
gsod.loc[gsod['precipitation_depth'] == 99.99, 'precipitation_depth'] = 0

# The DATE Field is a string and needs to be parsed, and then it will be helpful for filtering
# to break out the components of the date into separate fields.
gsod['date'] = pd.to_datetime(gsod['date'])
gsod['year'] = gsod['date'].dt.year
gsod['month'] = gsod['date'].dt.month
gsod['day_of_month'] = gsod['date'].dt.day
gsod['day_of_year'] = gsod['date'].dt.dayofyear

# Let's merge in the cloudcover data
merged_df = pd.merge(gsod, cloud_cover[['date', 'cloudcover']], on='date', how='left')
gsod = merged_df

print(gsod.head(10))
# Out:
#         date                   station_name  avg_temp  min_temp  max_temp  \
# 0 2000-01-01  CHICAGO MIDWAY AIRPORT, IL US      40.5      34.0      50.0
# 1 2000-01-02  CHICAGO MIDWAY AIRPORT, IL US      50.5      43.0      61.0
# 2 2000-01-03  CHICAGO MIDWAY AIRPORT, IL US      38.7      37.0      45.0
# 3 2000-01-04  CHICAGO MIDWAY AIRPORT, IL US      30.6      26.6      37.4
# 4 2000-01-05  CHICAGO MIDWAY AIRPORT, IL US      21.8      15.8      26.6
# 5 2000-01-06  CHICAGO MIDWAY AIRPORT, IL US      31.3      25.0      43.0
# 6 2000-01-07  CHICAGO MIDWAY AIRPORT, IL US      27.8      23.0      34.0
# 7 2000-01-08  CHICAGO MIDWAY AIRPORT, IL US      34.4      26.6      46.4
# 8 2000-01-09  CHICAGO MIDWAY AIRPORT, IL US      39.1      37.0      41.0
# 9 2000-01-10  CHICAGO MIDWAY AIRPORT, IL US      43.1      41.0      46.9
#
#    precipitation_depth  snow_depth   rain   snow  year  month  day_of_month  \
# 0                 0.00         0.0  False  False  2000      1             1
# 1                 0.01         0.0   True  False  2000      1             2
# 2                 0.01         0.0   True  False  2000      1             3
# 3                 0.15         0.0   True   True  2000      1             4
# 4                 0.01         0.0  False   True  2000      1             5
# 5                 0.00         0.0  False  False  2000      1             6
# 6                 0.00         0.0  False   True  2000      1             7
# 7                 0.00         0.0  False  False  2000      1             8
# 8                 0.14         0.0   True  False  2000      1             9
# 9                 0.13         0.0   True  False  2000      1            10
#
#    day_of_year  cloudcover
# 0            1        63.3
# 1            2        82.7
# 2            3       100.0
# 3            4        99.7
# 4            5        87.5
# 5            6        54.1
# 6            7        42.3
# 7            8        52.2
# 8            9       100.0
# 9           10        79.1

# %% [markdown]
# ## Weather Questions
#
# I've got some 🔥BURNING🔥 questions about the trends of weather in Chicago, and especially about our decline into 🥶COLD DAYS🥶.
#
# 1. How often have we had snowfall on Christmas? How much was there?
# 2. How often has it been above 40℉ on Christmas?
# 3. How often have we had Decembers where the temperature reaches at least 50℉ for more than one day in a row? How long is that streak?
# 4. What's the last day in December when the temperature was at least 50℉?
# 5. For each year, and for each month of the winter, what was the biggest temperature differential in a 2-day period?
# 6. As we approach winter, it feels like it sharply declines from warm temperatures (> 70℉) to cold temperatures (< 32℉). When does the first sub-freezing (< 32℉) temperature happen each Fall/Winter, and how long before that day was it still warm (> 70℉)?
# 7. Every year it feels like we have a very short Fall in Chicago, which I would characterize as a time during which the temperatures exist between 32℉ and 70℉. How long do the temperatures exist in this range?
# 8. When's the last Fall day (after September 22) when the temperature is at least 70℉?
# 9. When's the first Fall day (after September 22) that the temperature drops to below freezing?
# 10. When's the first Fall day (after September 22) that the temperature never gets above freezing?
#
# Having grown up in Doylestown, Pennsylvania I'm used to different winter weather. I want to also compare all of these answers to what has historically happened around my hometown and see if really is harsher in Chicago or if that's just my imagination.

# %% [markdown]
# ### 1. How often have we had snowfall on Christmas? How much was there?

# %%
gsod[(gsod['month'] == 12) & (gsod['day_of_month'] == 25) & gsod['snow'] & (gsod['snow_depth'] > 0)][['date', 'snow_depth']]
# Out:
#            date  snow_depth
# 1089 2002-12-25         3.1
# 2185 2005-12-25         1.2
# 3280 2008-12-25         5.1
# 3645 2009-12-25         1.2
# 4010 2010-12-25         7.1
# 6566 2017-12-25         2.0

# %% [markdown]
# Out of 50 years, we've only had 8 years where there was accumulated snow on Christmas!
#
# In 2010 and 2008 we had very significant snowfall on Christmas. We haven't had snow on Christmas since 2017.

# %% [markdown]
# ### 2. How often has it been above 40℉ on Christmas?

# %%
gsod[(gsod['month'] == 12) & (gsod['day_of_month'] == 25) & (gsod['max_temp'] > 40)][['date', 'max_temp']]
# Out:
#            date  max_temp
# 2550 2006-12-25      43.0
# 2915 2007-12-25      42.1
# 3645 2009-12-25      43.0
# 4375 2011-12-25      45.0
# 5471 2014-12-25      44.1
# 5836 2015-12-25      46.0
# 6931 2018-12-25      46.9
# 7296 2019-12-25      61.0
# 8027 2021-12-25      59.0
# 8757 2023-12-25      60.1

# %% [markdown]
# ### 3. How often have we had Decembers where the temperature reaches at least 50℉ for more than one day in a row? How long is that streak?

# %%
min_temp = 50
warm_days_by_year = gsod[(gsod['month'] == 12) & (gsod['max_temp'] >= min_temp)].groupby('year')
for year, data in warm_days_by_year:
    longest_streak = 1
    current_streak = 1
    for i in range(1, len(data)):
        if data.iloc[i]['day_of_month'] == data.iloc[i - 1]['day_of_month'] + 1:
            current_streak += 1
        else:
            longest_streak = current_streak
            current_streak = 1
    print(f"Longest streak of >={min_temp}℉ for December {year}: {longest_streak} days")
# Out:
# Longest streak of >=50℉ for December 2001: 1 days
# Longest streak of >=50℉ for December 2002: 2 days
# Longest streak of >=50℉ for December 2003: 1 days
# Longest streak of >=50℉ for December 2004: 2 days
# Longest streak of >=50℉ for December 2006: 2 days
# Longest streak of >=50℉ for December 2007: 1 days
# Longest streak of >=50℉ for December 2008: 1 days
# Longest streak of >=50℉ for December 2009: 1 days
# Longest streak of >=50℉ for December 2010: 1 days
# Longest streak of >=50℉ for December 2011: 2 days
# Longest streak of >=50℉ for December 2012: 3 days
# Longest streak of >=50℉ for December 2013: 3 days
# Longest streak of >=50℉ for December 2014: 1 days
# Longest streak of >=50℉ for December 2015: 1 days
# Longest streak of >=50℉ for December 2016: 1 days
# Longest streak of >=50℉ for December 2017: 5 days
# Longest streak of >=50℉ for December 2018: 4 days
# Longest streak of >=50℉ for December 2019: 6 days
# Longest streak of >=50℉ for December 2020: 3 days
# Longest streak of >=50℉ for December 2021: 6 days
# Longest streak of >=50℉ for December 2022: 2 days
# Longest streak of >=50℉ for December 2023: 1 days

# %% [markdown]
# ### 4. What's the last day in December when the temperature was at least 50℉?

# %%
print(f"Last day in December with max temperature >= {min_temp}℉")
for year, data in warm_days_by_year:
    print(f"{data.iloc[-1]['year']}, December {data.iloc[-1]['day_of_month']}: {data.iloc[-1]['max_temp']}℉")
# Out:
# Last day in December with max temperature >= 50℉
# 2001, December 6: 64.4℉
# 2002, December 31: 55.9℉
# 2003, December 10: 55.4℉
# 2004, December 31: 57.2℉
# 2006, December 31: 59.0℉
# 2007, December 23: 52.0℉
# 2008, December 28: 54.0℉
# 2009, December 2: 50.0℉
# 2010, December 31: 55.9℉
# 2011, December 19: 51.1℉
# 2012, December 20: 50.0℉
# 2013, December 28: 51.1℉
# 2014, December 27: 51.1℉
# 2015, December 24: 57.9℉
# 2016, December 26: 55.0℉
# 2017, December 19: 51.1℉
# 2018, December 28: 54.0℉
# 2019, December 30: 54.0℉
# 2020, December 24: 52.0℉
# 2021, December 25: 59.0℉
# 2022, December 30: 57.0℉
# 2023, December 26: 55.9℉

# %% [markdown]
# ### 5. For each year, and for each month of the winter, what was the biggest temperature differential in a 2-day period?

# %%
# First let's get just the data for winter months, which we'll consider to be December - March
winter = gsod[gsod['month'].isin([12, 1, 2, 3])].groupby(['year', 'month'])

for (year, month), group in winter:
    max_positive_diff = 0
    max_negative_diff = 0
    for i in range(1, len(group)):
        if group.iloc[i]['max_temp'] - group.iloc[i-1]['min_temp'] > max_positive_diff:
            max_positive_diff = group.iloc[i]['max_temp'] - group.iloc[i-1]['min_temp']
        if group.iloc[i]['min_temp'] - group.iloc[i-1]['max_temp'] < max_negative_diff:
            max_negative_diff = group.iloc[i]['min_temp'] - group.iloc[i-1]['max_temp']
    print(f"In any 2-day period, the biggest temperature increase in {month}/{year} was +{max_positive_diff} F.")
    print(f"In any 2-day period, the biggest temperature decrease in {month}/{year} was {max_negative_diff} F.")
# Out:
# In any 2-day period, the biggest temperature increase in 1/2000 was +28.3 F.
# In any 2-day period, the biggest temperature decrease in 1/2000 was -30.4 F.
# In any 2-day period, the biggest temperature increase in 2/2000 was +37.8 F.
# In any 2-day period, the biggest temperature decrease in 2/2000 was -25.9 F.
# In any 2-day period, the biggest temperature increase in 3/2000 was +40.9 F.
# In any 2-day period, the biggest temperature decrease in 3/2000 was -45.400000000000006 F.
# In any 2-day period, the biggest temperature increase in 12/2000 was +32.4 F.
# In any 2-day period, the biggest temperature decrease in 12/2000 was -32.6 F.
# In any 2-day period, the biggest temperature increase in 1/2001 was +24.1 F.
# In any 2-day period, the biggest temperature decrease in 1/2001 was -19.6 F.
# In any 2-day period, the biggest temperature increase in 2/2001 was +36.4 F.
# In any 2-day period, the biggest temperature decrease in 2/2001 was -39.6 F.
# In any 2-day period, the biggest temperature increase in 3/2001 was +26.1 F.
# In any 2-day period, the biggest temperature decrease in 3/2001 was -27.5 F.
# In any 2-day period, the biggest temperature increase in 12/2001 was +22.299999999999997 F.
# In any 2-day period, the biggest temperature decrease in 12/2001 was -29.5 F.
# In any 2-day period, the biggest temperature increase in 1/2002 was +34.7 F.
# In any 2-day period, the biggest temperature decrease in 1/2002 was -21.799999999999997 F.
# In any 2-day period, the biggest temperature increase in 2/2002 was +34.199999999999996 F.
# In any 2-day period, the biggest temperature decrease in 2/2002 was -31.799999999999997 F.
# In any 2-day period, the biggest temperature increase in 3/2002 was +40.2 F.
# In any 2-day period, the biggest temperature decrease in 3/2002 was -46.8 F.
# In any 2-day period, the biggest temperature increase in 12/2002 was +36.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2002 was -28.799999999999997 F.
# In any 2-day period, the biggest temperature increase in 1/2003 was +33.8 F.
# In any 2-day period, the biggest temperature decrease in 1/2003 was -32.0 F.
# In any 2-day period, the biggest temperature increase in 2/2003 was +27.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2003 was -34.9 F.
# In any 2-day period, the biggest temperature increase in 3/2003 was +39.6 F.
# In any 2-day period, the biggest temperature decrease in 3/2003 was -36.0 F.
# In any 2-day period, the biggest temperature increase in 12/2003 was +33.5 F.
# In any 2-day period, the biggest temperature decrease in 12/2003 was -36.0 F.
# In any 2-day period, the biggest temperature increase in 1/2004 was +32.8 F.
# In any 2-day period, the biggest temperature decrease in 1/2004 was -33.1 F.
# In any 2-day period, the biggest temperature increase in 2/2004 was +28.1 F.
# In any 2-day period, the biggest temperature decrease in 2/2004 was -27.2 F.
# In any 2-day period, the biggest temperature increase in 3/2004 was +39.8 F.
# In any 2-day period, the biggest temperature decrease in 3/2004 was -35.0 F.
# In any 2-day period, the biggest temperature increase in 12/2004 was +25.4 F.
# In any 2-day period, the biggest temperature decrease in 12/2004 was -36.0 F.
# In any 2-day period, the biggest temperature increase in 1/2005 was +33.2 F.
# In any 2-day period, the biggest temperature decrease in 1/2005 was -57.6 F.
# In any 2-day period, the biggest temperature increase in 2/2005 was +30.1 F.
# In any 2-day period, the biggest temperature decrease in 2/2005 was -18.5 F.
# In any 2-day period, the biggest temperature increase in 3/2005 was +38.0 F.
# In any 2-day period, the biggest temperature decrease in 3/2005 was -43.1 F.
# In any 2-day period, the biggest temperature increase in 12/2005 was +32.1 F.
# In any 2-day period, the biggest temperature decrease in 12/2005 was -23.0 F.
# In any 2-day period, the biggest temperature increase in 1/2006 was +33.8 F.
# In any 2-day period, the biggest temperature decrease in 1/2006 was -30.9 F.
# In any 2-day period, the biggest temperature increase in 2/2006 was +38.3 F.
# In any 2-day period, the biggest temperature decrease in 2/2006 was -40.0 F.
# In any 2-day period, the biggest temperature increase in 3/2006 was +29.199999999999996 F.
# In any 2-day period, the biggest temperature decrease in 3/2006 was -37.0 F.
# In any 2-day period, the biggest temperature increase in 12/2006 was +30.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2006 was -26.1 F.
# In any 2-day period, the biggest temperature increase in 1/2007 was +25.4 F.
# In any 2-day period, the biggest temperature decrease in 1/2007 was -34.9 F.
# In any 2-day period, the biggest temperature increase in 2/2007 was +31.799999999999997 F.
# In any 2-day period, the biggest temperature decrease in 2/2007 was -24.1 F.
# In any 2-day period, the biggest temperature increase in 3/2007 was +39.1 F.
# In any 2-day period, the biggest temperature decrease in 3/2007 was -39.099999999999994 F.
# In any 2-day period, the biggest temperature increase in 12/2007 was +33.099999999999994 F.
# In any 2-day period, the biggest temperature decrease in 12/2007 was -34.0 F.
# In any 2-day period, the biggest temperature increase in 1/2008 was +34.9 F.
# In any 2-day period, the biggest temperature decrease in 1/2008 was -49.8 F.
# In any 2-day period, the biggest temperature increase in 2/2008 was +42.2 F.
# In any 2-day period, the biggest temperature decrease in 2/2008 was -41.9 F.
# In any 2-day period, the biggest temperature increase in 3/2008 was +32.9 F.
# In any 2-day period, the biggest temperature decrease in 3/2008 was -32.0 F.
# In any 2-day period, the biggest temperature increase in 12/2008 was +43.6 F.
# In any 2-day period, the biggest temperature decrease in 12/2008 was -41.9 F.
# In any 2-day period, the biggest temperature increase in 1/2009 was +43.0 F.
# In any 2-day period, the biggest temperature decrease in 1/2009 was -30.1 F.
# In any 2-day period, the biggest temperature increase in 2/2009 was +43.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2009 was -32.1 F.
# In any 2-day period, the biggest temperature increase in 3/2009 was +36.0 F.
# In any 2-day period, the biggest temperature decrease in 3/2009 was -45.0 F.
# In any 2-day period, the biggest temperature increase in 12/2009 was +29.9 F.
# In any 2-day period, the biggest temperature decrease in 12/2009 was -34.1 F.
# In any 2-day period, the biggest temperature increase in 1/2010 was +27.0 F.
# In any 2-day period, the biggest temperature decrease in 1/2010 was -24.1 F.
# In any 2-day period, the biggest temperature increase in 2/2010 was +23.1 F.
# In any 2-day period, the biggest temperature decrease in 2/2010 was -21.9 F.
# In any 2-day period, the biggest temperature increase in 3/2010 was +45.0 F.
# In any 2-day period, the biggest temperature decrease in 3/2010 was -32.900000000000006 F.
# In any 2-day period, the biggest temperature increase in 12/2010 was +28.9 F.
# In any 2-day period, the biggest temperature decrease in 12/2010 was -29.299999999999997 F.
# In any 2-day period, the biggest temperature increase in 1/2011 was +24.0 F.
# In any 2-day period, the biggest temperature decrease in 1/2011 was -43.0 F.
# In any 2-day period, the biggest temperature increase in 2/2011 was +31.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2011 was -29.200000000000003 F.
# In any 2-day period, the biggest temperature increase in 3/2011 was +34.9 F.
# In any 2-day period, the biggest temperature decrease in 3/2011 was -31.800000000000004 F.
# In any 2-day period, the biggest temperature increase in 12/2011 was +31.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2011 was -31.1 F.
# In any 2-day period, the biggest temperature increase in 1/2012 was +36.9 F.
# In any 2-day period, the biggest temperature decrease in 1/2012 was -33.2 F.
# In any 2-day period, the biggest temperature increase in 2/2012 was +35.1 F.
# In any 2-day period, the biggest temperature decrease in 2/2012 was -25.1 F.
# In any 2-day period, the biggest temperature increase in 3/2012 was +48.1 F.
# In any 2-day period, the biggest temperature decrease in 3/2012 was -34.0 F.
# In any 2-day period, the biggest temperature increase in 12/2012 was +29.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2012 was -39.099999999999994 F.
# In any 2-day period, the biggest temperature increase in 1/2013 was +29.0 F.
# In any 2-day period, the biggest temperature decrease in 1/2013 was -47.5 F.
# In any 2-day period, the biggest temperature increase in 2/2013 was +43.1 F.
# In any 2-day period, the biggest temperature decrease in 2/2013 was -39.9 F.
# In any 2-day period, the biggest temperature increase in 3/2013 was +27.0 F.
# In any 2-day period, the biggest temperature decrease in 3/2013 was -26.6 F.
# In any 2-day period, the biggest temperature increase in 12/2013 was +33.8 F.
# In any 2-day period, the biggest temperature decrease in 12/2013 was -43.0 F.
# In any 2-day period, the biggest temperature increase in 1/2014 was +39.8 F.
# In any 2-day period, the biggest temperature decrease in 1/2014 was -45.9 F.
# In any 2-day period, the biggest temperature increase in 2/2014 was +29.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2014 was -28.799999999999997 F.
# In any 2-day period, the biggest temperature increase in 3/2014 was +43.0 F.
# In any 2-day period, the biggest temperature decrease in 3/2014 was -36.0 F.
# In any 2-day period, the biggest temperature increase in 12/2014 was +23.9 F.
# In any 2-day period, the biggest temperature decrease in 12/2014 was -25.0 F.
# In any 2-day period, the biggest temperature increase in 1/2015 was +34.0 F.
# In any 2-day period, the biggest temperature decrease in 1/2015 was -37.9 F.
# In any 2-day period, the biggest temperature increase in 2/2015 was +34.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2015 was -30.9 F.
# In any 2-day period, the biggest temperature increase in 3/2015 was +39.900000000000006 F.
# In any 2-day period, the biggest temperature decrease in 3/2015 was -41.099999999999994 F.
# In any 2-day period, the biggest temperature increase in 12/2015 was +34.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2015 was -25.4 F.
# In any 2-day period, the biggest temperature increase in 1/2016 was +43.1 F.
# In any 2-day period, the biggest temperature decrease in 1/2016 was -38.3 F.
# In any 2-day period, the biggest temperature increase in 2/2016 was +38.800000000000004 F.
# In any 2-day period, the biggest temperature decrease in 2/2016 was -30.0 F.
# In any 2-day period, the biggest temperature increase in 3/2016 was +34.900000000000006 F.
# In any 2-day period, the biggest temperature decrease in 3/2016 was -29.0 F.
# In any 2-day period, the biggest temperature increase in 12/2016 was +36.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2016 was -28.9 F.
# In any 2-day period, the biggest temperature increase in 1/2017 was +36.0 F.
# In any 2-day period, the biggest temperature decrease in 1/2017 was -31.9 F.
# In any 2-day period, the biggest temperature increase in 2/2017 was +38.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2017 was -32.1 F.
# In any 2-day period, the biggest temperature increase in 3/2017 was +51.1 F.
# In any 2-day period, the biggest temperature decrease in 3/2017 was -42.8 F.
# In any 2-day period, the biggest temperature increase in 12/2017 was +34.00000000000001 F.
# In any 2-day period, the biggest temperature decrease in 12/2017 was -36.0 F.
# In any 2-day period, the biggest temperature increase in 1/2018 was +31.799999999999997 F.
# In any 2-day period, the biggest temperature decrease in 1/2018 was -39.8 F.
# In any 2-day period, the biggest temperature increase in 2/2018 was +37.1 F.
# In any 2-day period, the biggest temperature decrease in 2/2018 was -39.9 F.
# In any 2-day period, the biggest temperature increase in 3/2018 was +27.0 F.
# In any 2-day period, the biggest temperature decrease in 3/2018 was -24.200000000000003 F.
# In any 2-day period, the biggest temperature increase in 12/2018 was +28.1 F.
# In any 2-day period, the biggest temperature decrease in 12/2018 was -30.1 F.
# In any 2-day period, the biggest temperature increase in 1/2019 was +37.1 F.
# In any 2-day period, the biggest temperature decrease in 1/2019 was -40.0 F.
# In any 2-day period, the biggest temperature increase in 2/2019 was +43.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2019 was -41.4 F.
# In any 2-day period, the biggest temperature increase in 3/2019 was +34.00000000000001 F.
# In any 2-day period, the biggest temperature decrease in 3/2019 was -32.0 F.
# In any 2-day period, the biggest temperature increase in 12/2019 was +33.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2019 was -33.8 F.
# In any 2-day period, the biggest temperature increase in 1/2020 was +32.9 F.
# In any 2-day period, the biggest temperature decrease in 1/2020 was -34.4 F.
# In any 2-day period, the biggest temperature increase in 2/2020 was +38.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2020 was -34.0 F.
# In any 2-day period, the biggest temperature increase in 3/2020 was +43.0 F.
# In any 2-day period, the biggest temperature decrease in 3/2020 was -34.6 F.
# In any 2-day period, the biggest temperature increase in 12/2020 was +27.9 F.
# In any 2-day period, the biggest temperature decrease in 12/2020 was -45.0 F.
# In any 2-day period, the biggest temperature increase in 1/2021 was +27.0 F.
# In any 2-day period, the biggest temperature decrease in 1/2021 was -26.1 F.
# In any 2-day period, the biggest temperature increase in 2/2021 was +32.9 F.
# In any 2-day period, the biggest temperature decrease in 2/2021 was -30.1 F.
# In any 2-day period, the biggest temperature increase in 3/2021 was +39.900000000000006 F.
# In any 2-day period, the biggest temperature decrease in 3/2021 was -33.99999999999999 F.
# In any 2-day period, the biggest temperature increase in 12/2021 was +32.9 F.
# In any 2-day period, the biggest temperature decrease in 12/2021 was -38.900000000000006 F.
# In any 2-day period, the biggest temperature increase in 1/2022 was +38.2 F.
# In any 2-day period, the biggest temperature decrease in 1/2022 was -34.0 F.
# In any 2-day period, the biggest temperature increase in 2/2022 was +38.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2022 was -45.9 F.
# In any 2-day period, the biggest temperature increase in 3/2022 was +43.900000000000006 F.
# In any 2-day period, the biggest temperature decrease in 3/2022 was -35.99999999999999 F.
# In any 2-day period, the biggest temperature increase in 12/2022 was +36.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2022 was -43.0 F.
# In any 2-day period, the biggest temperature increase in 1/2023 was +23.9 F.
# In any 2-day period, the biggest temperature decrease in 1/2023 was -22.0 F.
# In any 2-day period, the biggest temperature increase in 2/2023 was +42.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2023 was -33.0 F.
# In any 2-day period, the biggest temperature increase in 3/2023 was +41.8 F.
# In any 2-day period, the biggest temperature decrease in 3/2023 was -39.1 F.
# In any 2-day period, the biggest temperature increase in 12/2023 was +29.0 F.
# In any 2-day period, the biggest temperature decrease in 12/2023 was -25.0 F.
# In any 2-day period, the biggest temperature increase in 1/2024 was +32.1 F.
# In any 2-day period, the biggest temperature decrease in 1/2024 was -46.0 F.
# In any 2-day period, the biggest temperature increase in 2/2024 was +40.0 F.
# In any 2-day period, the biggest temperature decrease in 2/2024 was -50.900000000000006 F.
# In any 2-day period, the biggest temperature increase in 3/2024 was +38.9 F.
# In any 2-day period, the biggest temperature decrease in 3/2024 was -33.0 F.

# %% [markdown]
# ## First Fall day where the minimum temperature was < 32 F

# %%
minFreezingDays = gsod[(gsod['min_temp'] < 32) & (gsod['month'] > 8)]
# Group by year and get the first day_of_month and month values for each group
result1 = minFreezingDays.groupby('year').agg({'month': 'first', 'day_of_month': 'first'}).reset_index()

print(result1)
# Out:
#     year  month  day_of_month
# 0   2000     11            11
# 1   2001     11            20
# 2   2002     11             1
# 3   2003     11             7
# 4   2004     10            17
# 5   2005     11            10
# 6   2006     10            24
# 7   2007     11             7
# 8   2008     11            10
# 9   2009     10            11
# 10  2010     11             6
# 11  2011     11            11
# 12  2012     11             6
# 13  2013     10            22
# 14  2014     11             2
# 15  2015     11            14
# 16  2016     11            20
# 17  2017     11             8
# 18  2018     10            21
# 19  2019     11             1
# 20  2020     10            30
# 21  2021     11             3
# 22  2022     11            13
# 23  2023     10            31

# %% [markdown]
# ## First day where the maximum temperature was < 32 F (the whole day was below freezing)

# %%
maxFreezingDays = gsod[(gsod['max_temp'] < 32) & (gsod['month'] > 8)]
# Group by year and get the first day_of_month and month values for each group
result2 = maxFreezingDays.groupby('year').agg({'month': 'first', 'day_of_month': 'first'}).reset_index()

print(result2)
# Out:
#     year  month  day_of_month
# 0   2000     11            21
# 1   2001     12            24
# 2   2002     11            25
# 3   2003     12            12
# 4   2004     12            14
# 5   2005     11            17
# 6   2006     12             2
# 7   2007     11            23
# 8   2008     11            21
# 9   2009     12            10
# 10  2010     12             1
# 11  2011     12            10
# 12  2013     11            24
# 13  2014     11            13
# 14  2015     11            22
# 15  2016     12             8
# 16  2017     12            24
# 17  2018     11            13
# 18  2019     11            12
# 19  2020     12            25
# 20  2021     12             7
# 21  2022     11            19
# 22  2023     11            28

# %% [markdown]
# ## Last Fall day where the maximum temperature was > 70 F

# %%
maxWarmDays = gsod[(gsod['max_temp'] > 70) & (gsod['month'] > 8)]
# Group by YEAR and get the first DAY_OF_MONTH and MONTH values for each group
result3 = maxWarmDays.groupby('year').agg({'month': 'last', 'day_of_month': 'last'}).reset_index()

print(result3)
# Out:
#     year  month  day_of_month
# 0   2000     11             1
# 1   2001     11             7
# 2   2002     10            12
# 3   2003     10            30
# 4   2004     10            30
# 5   2005     10            18
# 6   2006     11             9
# 7   2007     10            22
# 8   2008     11             5
# 9   2009     11             8
# 10  2010     10            26
# 11  2011     11            13
# 12  2012     12             3
# 13  2013     10            12
# 14  2014     10            28
# 15  2015     11             5
# 16  2016     11            17
# 17  2017     10            22
# 18  2018     10            10
# 19  2019     10            11
# 20  2020     11            10
# 21  2021     10            20
# 22  2022     11            10
# 23  2023     11             6
